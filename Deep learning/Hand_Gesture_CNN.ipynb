# %% [markdown]
# # Flow
# ### Have dataset for hand open and close.
#
# ### Train the dataset using CNN
#
# ### Save the best model
#
# ### Using open cv or yolo access camera and take picture of the input
#
# ### Give it to model then model well predict open or close hands
#
# ### And return result

# %%
# import lib
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
# CNN

# Convulation -> ReLU -> Pooling
    # Convulation -> DotProduct
    # ReLU -> Max(0, X) -> Removes linearity
    # Pooling -> MaxValue() -> reduce size

# Flattern -> Cause we need to send it to Dense layer

# Dense (W * X + B)
# Softmax
# Cross Entropy loss

# %%
# How to import a image

# %%
t
